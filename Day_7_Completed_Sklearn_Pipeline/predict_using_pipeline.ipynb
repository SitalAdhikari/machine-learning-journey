# %%
import numpy as np
import pickle

# %%
#loading
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
#Assume user input
test_input = np.array([1,'female',22,0,0, 400,'S'], dtype=object).reshape(1,7)

# %%
print(pipe.predict(test_input))
# Out:
# [0]
# /home/sital/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/sital/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
