# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('titanic_dataset.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 164         1056         0       2
# 253         1145         0       3
# 93           985         0       3
# 15           907         1       2
# 189         1081         0       2
#
#                                               Name     Sex   Age  SibSp  \
# 164                  Peruschitz, Rev. Joseph Maria    male  41.0      0
# 253                       Salander, Mr. Karl Johan    male  24.0      0
# 93                               Guest, Mr. Robert    male   NaN      0
# 15   del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 189                                Veal, Mr. James    male  40.0      0
#
#      Parch         Ticket     Fare Cabin Embarked
# 164      0         237393  13.0000   NaN        S
# 253      0           7266   9.3250   NaN        S
# 93       0         376563   8.0500   NaN        S
# 15       0  SC/PARIS 2167  27.7208   NaN        C
# 189      0          28221  13.0000   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.shape
# Out:
# (418, 12)

# %%
df.dropna(inplace = True)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 122         1014         1       1  Schabert, Mrs. Paul (Emma Mock)  female
# 57           949         0       3    Abelseth, Mr. Olaus Jorgensen    male
# 28           920         0       1          Brady, Mr. John Bertram    male
# 75           967         0       1               Keeping, Mr. Edwin    male
# 208         1100         1       1    Rosenbaum, Miss. Edith Louise  female
#
#       Age  SibSp  Parch    Ticket      Fare  Cabin Embarked
# 122  35.0      1      0     13236   57.7500    C28        C
# 57   25.0      0      0    348122    7.6500  F G63        S
# 28   41.0      0      0    113054   30.5000    A21        S
# 75   32.5      0      0    113503  211.5000   C132        C
# 208  33.0      0      0  PC 17613   27.7208    A11        C

# %%
# # here, cabin has mixture of both numberical and alphabets.
# # no  mix of both (type 2-> copy)

# # for data: 1 2 3 A C 3 G 7 S
# df['column'].unique()

# #extract numerical:
# df['numerical_col'] = pd.to_numeric(df['column'], errors='coerce', downcast = 'integer')
# #extract categorical part:
# df['categorical_col'] = np.where(df['numerical_col'].isnull(), df['numerical_col'], np.nan)

# %%
# Cabin -> mixture
df['Cabin'].unique()
# Out:
# <StringArray>
# [            'B45',             'E31', 'B57 B59 B63 B66',             'B36',
#              'A21',             'C78',             'D19',              'A9',
#              'D15',             'C31',     'C23 C25 C27',           'F G63',
#              'B61',             'C53',             'D43',            'C130',
#             'C132',            'C101',         'C55 C57',             'B71',
#              'C46',            'C116',               'F',             'A29',
#               'G6',              'C6',             'C28',             'C51',
#              'C54',             'C97',             'D22',             'B10',
#               'F4',             'E45',             'E52',             'D30',
#          'B58 B60',             'E34',         'C62 C64',             'A11',
#              'B11',             'C80',             'F33',             'C85',
#              'D37',             'C86',             'D21',             'C89',
# ...

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)') #to captures numerical part
df['cabin_cat'] = df['Cabin'].str[0] #capture the first letter

df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_4283/2360203888.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['cabin_num'] = df['Cabin'].str.extract('(\d+)') #to captures numerical part
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
# ...

# %%
# we can also do in ticket too.
