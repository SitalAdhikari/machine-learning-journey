# %%
df = pd.read_csv('2_Student_Marks.csv')
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
courses = df['number_courses'].value_counts()
plt.pie(courses.index, labels=courses.values, autopct='%1.1f%%' )
plt.show()
# Out:
# Index([3, 4, 6, 8, 7, 5], dtype='int64', name='number_courses')
# [22 21 16 16 15 10]
